# %%
# pip install pyforest

# %%
import pyforest

# %%
df = pd.read_csv(r'C:\Users\HP Pavilion\Desktop\Demo\50_Startups.csv')

# %%
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
# pip install matplotlib

# %%
import matplotlib.pyplot as plt
#  matplotlib_inline

# %% [markdown]
# # EDA

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# #### Histograms

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
fig, axs = plt.subplots(1, 3, figsize=(15, 5))

# Univariate analysis for 'R&D Spend'
sns.histplot(df['R&D Spend'], kde=True, bins=20, color='skyblue', ax=axs[0])
axs[0].set_title('R&D Spend')
axs[0].set_xlabel('R&D Spend')
axs[0].set_ylabel('Frequency')

# Univariate analysis for 'Administration'
sns.histplot(df['Administration'], kde=True, bins=20, color='lightcoral', ax=axs[1])
axs[1].set_title('Administration')
axs[1].set_xlabel('Administration')
axs[1].set_ylabel('Frequency')

# Univariate analysis for 'Marketing Spend'
sns.histplot(df['Marketing Spend'], kde=True, bins=20, color='mediumseagreen', ax=axs[2])
axs[2].set_title('Marketing Spend')
axs[2].set_xlabel('Marketing Spend')
axs[2].set_ylabel('Frequency')

# Adjust layout for better spacing
plt.tight_layout()

# Show the subplots
plt.show()

# %%
# Univariate analysis for 'R&D Spend'
plt.figure(figsize=(8, 6))
sns.histplot(df['R&D Spend'], kde=True, bins=20, color='skyblue')
plt.title('Histogram of R&D Spend')
plt.xlabel('R&D Spend')
plt.ylabel('Frequency')
plt.show()

# # Univariate analysis for 'Administration'
# plt.figure(figsize=(8, 6))
# sns.histplot(df['Administration'], kde=True, bins=20, color='lightcoral')
# plt.title('Histogram of Administration')
# plt.xlabel('Administration')
# plt.ylabel('Frequency')
# plt.show()

# # Univariate analysis for 'Marketing Spend'
# plt.figure(figsize=(8, 6))
# sns.histplot(df['Marketing Spend'], kde=True, bins=20, color='mediumseagreen')
# plt.title('Histogram of Marketing Spend')
# plt.xlabel('Marketing Spend')
# plt.ylabel('Frequency')
# plt.show()

# %% [markdown]
# ### Box Plots

# %%
# Create subplots for box plots
fig, axs = plt.subplots(1, 3, figsize=(15, 5))

# Box Plots
sns.boxplot(x='R&D Spend', data=df, ax=axs[0], color='skyblue')
axs[0].set_title('R&D Spend - Box Plot')
axs[0].set_xlabel('R&D Spend')

sns.boxplot(x='Administration', data=df, ax=axs[1], color='lightcoral')
axs[1].set_title('Administration - Box Plot')
axs[1].set_xlabel('Administration')

sns.boxplot(x='Marketing Spend', data=df, ax=axs[2], color='mediumseagreen')
axs[2].set_title('Marketing Spend - Box Plot')
axs[2].set_xlabel('Marketing Spend')

# Adjust layout for better spacing
plt.tight_layout()

# Show the subplots
plt.show()

# %%
# Box plot
plt.figure(figsize=(8, 6))
sns.boxplot(x=df['Administration'], color='lightcoral')
plt.title('Box Plot of Administration')
plt.xlabel('Administration')
plt.show()

# %% [markdown]
# ### Violin Plots

# %%
# Create subplots for violin plots
fig, axs = plt.subplots(1, 3, figsize=(15, 5))
# Violin Plots
sns.violinplot(x='R&D Spend', data=df, ax=axs[0], color='skyblue')
axs[0].set_title('R&D Spend - Violin Plot')
axs[0].set_xlabel('R&D Spend')

sns.violinplot(x='Administration', data=df, ax=axs[1], color='lightcoral')
axs[1].set_title('Administration - Violin Plot')
axs[1].set_xlabel('Administration')

sns.violinplot(x='Marketing Spend', data=df, ax=axs[2], color='mediumseagreen')
axs[2].set_title('Marketing Spend - Violin Plot')
axs[2].set_xlabel('Marketing Spend')

# Adjust layout for better spacing
plt.tight_layout()

# Show the subplots
plt.show()

# %%
# Box plot
plt.figure(figsize=(8, 6))
sns.violinplot(x='Administration', data=df, color='lightcoral')
plt.title('Box Plot of Administration')
plt.xlabel('Administration')
plt.show()

# %% [markdown]
# ## Bivariate Analysis

# %%
fig, axs = plt.subplots(1, 3, figsize=(15, 5))  # 1 row, 3 columns

# Scatter plot for R&D Spend vs Profit
axs[0].scatter(df['R&D Spend'], df['Profit'], color='blue')
axs[0].set_title('R&D Spend vs Profit')
axs[0].set_xlabel('R&D Spend')
axs[0].set_ylabel('Profit')

# Scatter plot for Administration vs Profit
axs[1].scatter(df['Administration'], df['Profit'], color='green')
axs[1].set_title('Administration vs Profit')
axs[1].set_xlabel('Administration')
axs[1].set_ylabel('Profit')

# Scatter plot for Marketing Spend vs Profit
axs[2].scatter(df['Marketing Spend'], df['Profit'], color='red')
axs[2].set_title('Marketing Spend vs Profit')
axs[2].set_xlabel('Marketing Spend')
axs[2].set_ylabel('Profit')

# Adjust layout for better spacing
plt.tight_layout()

# Show the plots
plt.show()

# %%
# Scatter plot for R&D Spend vs Profit
plt.scatter(df['R&D Spend'], df['Profit'], color='blue')
plt.title('R&D Spend vs Profit')
plt.xlabel('R&D Spend')
plt.ylabel('Profit')
# Out:
# Text(0, 0.5, 'Profit')

# %% [markdown]
# ## Preprocessing

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
x.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State
# 0  165349.20       136897.80        471784.10    New York
# 1  162597.70       151377.59        443898.53  California
# 2  153441.51       101145.55        407934.54     Florida
# 3  144372.41       118671.85        383199.62    New York
# 4  142107.34        91391.77        366168.42     Florida

# %%
y.head()
# Out:
# 0    192261.83
# 1    191792.06
# 2    191050.39
# 3    182901.99
# 4    166187.94
# Name: Profit, dtype: float64

# %%
states = pd.get_dummies(x['State'],drop_first = True)

# %%
states =states.astype(int)

# %%
states.head()
# Out:
#    Florida  New York
# 0        0         1
# 1        0         0
# 2        1         0
# 3        0         1
# 4        1         0

# %%
x= x.drop('State',axis = 1)

# %%
x = pd.concat([x,states],axis=1)

# %%
x.head()
# Out:
#    R&D Spend  Administration  Marketing Spend  Florida  New York
# 0  165349.20       136897.80        471784.10        0         1
# 1  162597.70       151377.59        443898.53        0         0
# 2  153441.51       101145.55        407934.54        1         0
# 3  144372.41       118671.85        383199.62        0         1
# 4  142107.34        91391.77        366168.42        1         0

# %% [markdown]
# ## Fitting the Model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 42)

# %%
lin_regressor = LinearRegression()

# %%
lin_regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lin_regressor.predict(x_test)

# %%
y_pred
# Out:
# array([126362.87908255,  84608.45383634,  99677.49425147,  46357.46068582,
#        128750.48288504,  50912.4174188 , 109741.35032702, 100643.24281647,
#         97599.27574594, 113097.42524432])

# %%
comparison_df = pd.DataFrame({'y_true': y_test, 'y_pred': y_pred})


comparison_df
# Out:
#        y_true         y_pred
# 13  134307.35  126362.879083
# 39   81005.76   84608.453836
# 30   99937.59   99677.494251
# 45   64926.08   46357.460686
# 17  125370.37  128750.482885
# 48   35673.41   50912.417419
# 26  105733.54  109741.350327
# 25  107404.34  100643.242816
# 32   97427.84   97599.275746
# 19  122776.86  113097.425244

# %%
from sklearn.metrics import r2_score,mean_squared_error

# %%
r2 = r2_score(y_test,y_pred)

# %%
r2
# Out:
# 0.8987266414328636

# %% [markdown]
# ##### R2 = 0.89 which is nearer to 1 , so we can conclude that our model is giving better results with high accuracy.

# %%
mse =  mean_squared_error(y_test,y_pred)
mse
# Out:
# 82010363.04430112

# %% [markdown]
# ## Checking for Multicolinearty

# %%
# pip install statsmodels

# %%
# import statsmodels.api as sm

# %%
# model = sm.OLS(y,x).fit()

# %%
# model.summary()

# %%
# x.iloc[:,:].corr()

# %% [markdown]
# #### From above we can conclude there is no multicolinearty.
